# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/test.csv')
df.head(5)
df.tail()
# Out:
#             ID Customer_ID      Month            Name   Age          SSN  \
# 49995  0x25fe5  CUS_0x8600   December  Sarah McBridec  4975  031-35-0942
# 49996  0x25fee  CUS_0x942c  September           Nicks    25  078-73-5990
# 49997  0x25fef  CUS_0x942c    October           Nicks    25  078-73-5990
# 49998  0x25ff0  CUS_0x942c   November           Nicks    25  078-73-5990
# 49999  0x25ff1  CUS_0x942c   December           Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 49995  Architect      20002.88            1929.906667                 10  ...
# 49996   Mechanic      39628.99                    NaN                  4  ...
# 49997   Mechanic      39628.99            3359.415833                  4  ...
# 49998   Mechanic      39628.99                    NaN                  4  ...
# 49999   Mechanic      39628.99            3359.415833                  4  ...
#
#        Num_Credit_Inquiries  Credit_Mix Outstanding_Debt  \
# 49995                  12.0           _           3571.7
# 49996                   7.0        Good           502.38
# 49997                   7.0        Good           502.38
# 49998                   7.0        Good           502.38
# 49999                   7.0           _           502.38
#
#       Credit_Utilization_Ratio      Credit_History_Age Payment_of_Min_Amount  \
# 49995                34.780553                     NaN                   Yes
# 49996                27.758522  31 Years and 11 Months                    NM
# 49997                36.858542   32 Years and 0 Months                    No
# 49998                39.139840   32 Years and 1 Months                    No
# 49999                34.108530   32 Years and 2 Months                    No
#
#       Total_EMI_per_month  Amount_invested_monthly  \
# 49995           60.964772       146.48632477751087
# 49996           35.104023       181.44299902757518
# 49997           35.104023                __10000__
# 49998           35.104023        97.59857973344877
# 49999           35.104023       220.45787812168732
#
#                      Payment_Behaviour     Monthly_Balance
# 49995   Low_spent_Small_value_payments  275.53956951573343
# 49996   Low_spent_Small_value_payments  409.39456169535066
# 49997   Low_spent_Large_value_payments   349.7263321025098
# 49998  High_spent_Small_value_payments  463.23898098947717
# 49999  Low_spent_Medium_value_payments  360.37968260123847
#
# [5 rows x 27 columns]

# %%
pd.set_option('display.max_columns', None)
df.tail(5)
# Out:
#             ID Customer_ID      Month            Name   Age          SSN  \
# 49995  0x25fe5  CUS_0x8600   December  Sarah McBridec  4975  031-35-0942
# 49996  0x25fee  CUS_0x942c  September           Nicks    25  078-73-5990
# 49997  0x25fef  CUS_0x942c    October           Nicks    25  078-73-5990
# 49998  0x25ff0  CUS_0x942c   November           Nicks    25  078-73-5990
# 49999  0x25ff1  CUS_0x942c   December           Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 49995  Architect      20002.88            1929.906667                 10
# 49996   Mechanic      39628.99                    NaN                  4
# 49997   Mechanic      39628.99            3359.415833                  4
# 49998   Mechanic      39628.99                    NaN                  4
# 49999   Mechanic      39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 49995                8             29           5
# 49996                6              7          2_
# 49997                6              7           2
# 49998                6              7          2_
# 49999                6              7           2
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 49995  Personal Loan, Auto Loan, Mortgage Loan, Stude...                   33
# 49996                        Auto Loan, and Student Loan                   20
# 49997                        Auto Loan, and Student Loan                   23
# 49998                        Auto Loan, and Student Loan                   21
# 49999                        Auto Loan, and Student Loan                   22
#
#       Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 49995                     25                18.31                  12.0
# 49996                    NaN                 11.5                   7.0
# 49997                      5                 13.5                   7.0
# 49998                     6_                 11.5                   7.0
# 49999                      5                 11.5                   7.0
#
#       Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 49995          _           3571.7                 34.780553
# 49996       Good           502.38                 27.758522
# 49997       Good           502.38                 36.858542
# 49998       Good           502.38                 39.139840
# 49999          _           502.38                 34.108530
#
#            Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 49995                     NaN                   Yes            60.964772
# 49996  31 Years and 11 Months                    NM            35.104023
# 49997   32 Years and 0 Months                    No            35.104023
# 49998   32 Years and 1 Months                    No            35.104023
# 49999   32 Years and 2 Months                    No            35.104023
#
#       Amount_invested_monthly                Payment_Behaviour  \
# 49995      146.48632477751087   Low_spent_Small_value_payments
# 49996      181.44299902757518   Low_spent_Small_value_payments
# 49997               __10000__   Low_spent_Large_value_payments
# 49998       97.59857973344877  High_spent_Small_value_payments
# 49999      220.45787812168732  Low_spent_Medium_value_payments
#
#           Monthly_Balance
# 49995  275.53956951573343
# 49996  409.39456169535066
# 49997   349.7263321025098
# 49998  463.23898098947717
# 49999  360.37968260123847

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Customer_ID               50000 non-null  object
#  2   Month                     50000 non-null  object
#  3   Name                      44985 non-null  object
#  4   Age                       50000 non-null  object
#  5   SSN                       50000 non-null  object
#  6   Occupation                50000 non-null  object
#  7   Annual_Income             50000 non-null  object
#  8   Monthly_Inhand_Salary     42502 non-null  float64
#  9   Num_Bank_Accounts         50000 non-null  int64
#  10  Num_Credit_Card           50000 non-null  int64
#  11  Interest_Rate             50000 non-null  int64
#  12  Num_of_Loan               50000 non-null  object
#  13  Type_of_Loan              44296 non-null  object
#  14  Delay_from_due_date       50000 non-null  int64
#  15  Num_of_Delayed_Payment    46502 non-null  object
#  16  Changed_Credit_Limit      50000 non-null  object
#  17  Num_Credit_Inquiries      48965 non-null  float64
#  18  Credit_Mix                50000 non-null  object
#  19  Outstanding_Debt          50000 non-null  object
#  20  Credit_Utilization_Ratio  50000 non-null  float64
#  21  Credit_History_Age        45530 non-null  object
#  22  Payment_of_Min_Amount     50000 non-null  object
#  23  Total_EMI_per_month       50000 non-null  float64
#  24  Amount_invested_monthly   47729 non-null  object
#  25  Payment_Behaviour         50000 non-null  object
#  26  Monthly_Balance           49438 non-null  object
# dtypes: float64(4), int64(4), object(19)
# memory usage: 10.3+ MB

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
df["Annual_Income"]=df["Annual_Income"].str.replace("_","")
df["Annual_Income"]
# Out:
# 0        19114.12
# 1        19114.12
# 2        19114.12
# 3        19114.12
# 4        34847.84
#            ...
# 49995    20002.88
# 49996    39628.99
# 49997    39628.99
# 49998    39628.99
# 49999    39628.99
# Name: Annual_Income, Length: 50000, dtype: object

# %%
df.head(10)
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
# 5  0x1617  CUS_0x21b1    October  Rick Rothackerj   28    #F%$D@*&8
# 6  0x1618  CUS_0x21b1   November  Rick Rothackerj   28  004-07-5839
# 7  0x1619  CUS_0x21b1   December  Rick Rothackerj   28  004-07-5839
# 8  0x1622  CUS_0x2dbc  September           Langep   35  486-85-3974
# 9  0x1623  CUS_0x2dbc    October           Langep   35  486-85-3974
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  Scientist      19114.12            1824.843333                  3
# 1  Scientist      19114.12            1824.843333                  3
# 2  Scientist      19114.12            1824.843333                  3
# 3  Scientist      19114.12                    NaN                  3
# 4    _______      34847.84            3037.986667                  2
# 5    Teacher      34847.84            3037.986667                  2
# 6    Teacher      34847.84            3037.986667                  2
# 7    Teacher      34847.84            3037.986667                  2
# 8   Engineer     143162.64                    NaN                  1
# 9   Engineer     143162.64           12187.220000                  1
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                4              3           4
# 1                4              3           4
# 2                4              3           4
# 3                4              3           4
# 4                4              6           1
# 5                4              6           1
# 6                4              6           1
# 7                4              6           1
# 8                5              8           3
# 9                5              8           3
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 2  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# 3  Auto Loan, Credit-Builder Loan, Personal Loan,...                    4
# 4                                Credit-Builder Loan                    3
# 5                                Credit-Builder Loan                    3
# 6                                Credit-Builder Loan                    3
# 7                                Credit-Builder Loan                    3
# 8            Auto Loan, Auto Loan, and Not Specified                    8
# 9            Auto Loan, Auto Loan, and Not Specified                    6
#
#   Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                      7                11.27                2022.0
# 1                      9                13.27                   4.0
# 2                      4                12.27                   4.0
# 3                      5                11.27                   4.0
# 4                      1                 5.42                   5.0
# 5                      3                 5.42                   5.0
# 6                    NaN                 5.42                   5.0
# 7                     2_                 7.42                   5.0
# 8                   1942                  7.1                   3.0
# 9                      3                  2.1                   3.0
#
#   Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 0       Good           809.98                 35.030402
# 1       Good           809.98                 33.053114
# 2       Good           809.98                 33.811894
# 3       Good           809.98                 32.430559
# 4       Good           605.03                 25.926822
# 5       Good           605.03                 30.116600
# 6          _           605.03                 30.996424
# 7          _           605.03                 33.875167
# 8       Good          1303.01                 35.229707
# 9       Good          1303.01                 35.685836
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No            49.574949
# 1  22 Years and 10 Months                    No            49.574949
# 2                     NaN                    No            49.574949
# 3   23 Years and 0 Months                    No            49.574949
# 4   27 Years and 3 Months                    No            18.816215
# 5   27 Years and 4 Months                    No            18.816215
# 6   27 Years and 5 Months                    No            18.816215
# 7   27 Years and 6 Months                    No            18.816215
# 8   18 Years and 5 Months                    No           246.992319
# 9   18 Years and 6 Months                    No           246.992319
#
#   Amount_invested_monthly                 Payment_Behaviour  \
# 0      236.64268203272135    Low_spent_Small_value_payments
# 1      21.465380264657146  High_spent_Medium_value_payments
# 2      148.23393788500925   Low_spent_Medium_value_payments
# 3       39.08251089460281  High_spent_Medium_value_payments
# 4      39.684018417945296   High_spent_Large_value_payments
# 5      251.62736875017606    Low_spent_Large_value_payments
# 6       72.68014533363515   High_spent_Large_value_payments
# 7      153.53448761392985                            !@9#%8
# 8      397.50365354404653   Low_spent_Medium_value_payments
# 9       453.6151305781054    Low_spent_Large_value_payments
#
#       Monthly_Balance
# 0  186.26670208571772
# 1  361.44400385378196
# 2  264.67544623342997
# 3  343.82687322383634
# 4   485.2984336755923
# 5   303.3550833433617
# 6  452.30230675990265
# 7  421.44796447960783
# 8   854.2260270022115
# 9   788.1145499681528

# %%
df.fillna(np.mean,axis=1,inplace=True)
df.head(20)
# Out:
#         ID Customer_ID      Month                               Name  Age  \
# 0   0x160a   CUS_0xd40  September                      Aaron Maashoh   23
# 1   0x160b   CUS_0xd40    October                      Aaron Maashoh   24
# 2   0x160c   CUS_0xd40   November                      Aaron Maashoh   24
# 3   0x160d   CUS_0xd40   December                      Aaron Maashoh  24_
# 4   0x1616  CUS_0x21b1  September                    Rick Rothackerj   28
# 5   0x1617  CUS_0x21b1    October                    Rick Rothackerj   28
# 6   0x1618  CUS_0x21b1   November                    Rick Rothackerj   28
# 7   0x1619  CUS_0x21b1   December                    Rick Rothackerj   28
# 8   0x1622  CUS_0x2dbc  September                             Langep   35
# 9   0x1623  CUS_0x2dbc    October                             Langep   35
# 10  0x1624  CUS_0x2dbc   November  <function mean at 0x7d2a649015a0>   35
# 11  0x1625  CUS_0x2dbc   December                             Langep   35
# 12  0x162e  CUS_0xb891  September                             Jasond   55
# 13  0x162f  CUS_0xb891    October                             Jasond   55
# 14  0x1630  CUS_0xb891   November                             Jasond   55
# 15  0x1631  CUS_0xb891   December                             Jasond   55
# 16  0x163a  CUS_0x1cdb  September                             Deepaa   22
# 17  0x163b  CUS_0x1cdb    October                             Deepaa   22
# 18  0x163c  CUS_0x1cdb   November                             Deepaa   22
# 19  0x163d  CUS_0x1cdb   December                             Deepaa   22
#
#             SSN    Occupation Annual_Income  \
# 0   821-00-0265     Scientist      19114.12
# 1   821-00-0265     Scientist      19114.12
# 2   821-00-0265     Scientist      19114.12
# 3   821-00-0265     Scientist      19114.12
# 4   004-07-5839       _______      34847.84
# 5     #F%$D@*&8       Teacher      34847.84
# 6   004-07-5839       Teacher      34847.84
# 7   004-07-5839       Teacher      34847.84
# 8   486-85-3974      Engineer     143162.64
# 9   486-85-3974      Engineer     143162.64
# 10  486-85-3974      Engineer     143162.64
# 11  486-85-3974      Engineer     143162.64
# 12  072-31-6145  Entrepreneur      30689.89
# 13  072-31-6145  Entrepreneur      30689.89
# 14  072-31-6145  Entrepreneur      30689.89
# 15  072-31-6145  Entrepreneur     4148862.0
# 16  615-06-7821     Developer      35547.71
# 17    #F%$D@*&8     Developer      35547.71
# 18  615-06-7821     Developer      35547.71
# 19  615-06-7821     Developer      35547.71
#
#                 Monthly_Inhand_Salary Num_Bank_Accounts Num_Credit_Card  \
# 0                         1824.843333                 3               4
# 1                         1824.843333                 3               4
# 2                         1824.843333                 3               4
# 3   <function mean at 0x7d2a649015a0>                 3               4
# 4                         3037.986667                 2               4
# 5                         3037.986667                 2               4
# 6                         3037.986667                 2               4
# 7                         3037.986667                 2               4
# 8   <function mean at 0x7d2a649015a0>                 1               5
# 9                            12187.22                 1               5
# 10                           12187.22                 1               5
# 11                           12187.22                 1               5
# 12                        2612.490833                 2               5
# 13                        2612.490833                 2               5
# 14                        2612.490833                 2               5
# 15                        2612.490833                 2               5
# 16                        2853.309167                 7               5
# 17                        2853.309167                 7               5
# 18                        2853.309167                 7               5
# 19                        2853.309167                 7               5
#
#    Interest_Rate Num_of_Loan  \
# 0              3           4
# 1              3           4
# 2              3           4
# 3              3           4
# 4              6           1
# 5              6           1
# 6              6           1
# 7              6           1
# 8              8           3
# 9              8           3
# 10             8        1381
# 11             8           3
# 12             4           1
# 13             4        -100
# 14             4           1
# 15             4           1
# 16             5           0
# 17             5           0
# 18             5        -100
# 19             5           0
#
#                                          Type_of_Loan Delay_from_due_date  \
# 0   Auto Loan, Credit-Builder Loan, Personal Loan,...                   3
# 1   Auto Loan, Credit-Builder Loan, Personal Loan,...                   3
# 2   Auto Loan, Credit-Builder Loan, Personal Loan,...                  -1
# 3   Auto Loan, Credit-Builder Loan, Personal Loan,...                   4
# 4                                 Credit-Builder Loan                   3
# 5                                 Credit-Builder Loan                   3
# 6                                 Credit-Builder Loan                   3
# 7                                 Credit-Builder Loan                   3
# 8             Auto Loan, Auto Loan, and Not Specified                   8
# 9             Auto Loan, Auto Loan, and Not Specified                   6
# 10            Auto Loan, Auto Loan, and Not Specified                   8
# 11            Auto Loan, Auto Loan, and Not Specified                   8
# 12                                      Not Specified                   5
# 13                                      Not Specified                   5
# 14                                      Not Specified                   5
# 15                                      Not Specified                   6
# 16                  <function mean at 0x7d2a649015a0>                   5
# 17                  <function mean at 0x7d2a649015a0>                   5
# 18                  <function mean at 0x7d2a649015a0>                   5
# 19                  <function mean at 0x7d2a649015a0>                   5
#
#                Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                                   7                11.27
# 1                                   9                13.27
# 2                                   4                12.27
# 3                                   5                11.27
# 4                                   1                 5.42
# 5                                   3                 5.42
# 6   <function mean at 0x7d2a649015a0>                 5.42
# 7                                  2_                 7.42
# 8                                1942                  7.1
# 9                                   3                  2.1
# 10                                  5                  7.1
# 11                                  6                  7.1
# 12                                  6                 1.99
# 13                                  8                 1.99
# 14                                  6                 1.99
# 15                                  6                 1.99
# 16                                 15                 2.58
# 17                                 18                 2.58
# 18                                 15                 2.58
# 19                                 18                 2.58
#
#    Num_Credit_Inquiries Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# 0                2022.0       Good           809.98                35.030402
# 1                   4.0       Good           809.98                33.053114
# 2                   4.0       Good           809.98                33.811894
# 3                   4.0       Good           809.98                32.430559
# 4                   5.0       Good           605.03                25.926822
# 5                   5.0       Good           605.03                  30.1166
# 6                   5.0          _           605.03                30.996424
# 7                   5.0          _           605.03                33.875167
# 8                   3.0       Good          1303.01                35.229707
# 9                   3.0       Good          1303.01                35.685836
# 10                  5.0       Good         1303.01_                31.819845
# 11                  5.0       Good          1303.01                33.707169
# 12                  4.0       Good           632.46                39.377219
# 13                  4.0          _           632.46                36.280475
# 14                  4.0       Good           632.46                36.824468
# 15                  7.0       Good           632.46                35.579265
# 16                  4.0          _           943.86                34.729842
# 17                  5.0   Standard           943.86                31.652351
# 18                  5.0   Standard           943.86                36.424835
# 19                  5.0   Standard           943.86                29.566123
#
#                    Credit_History_Age Payment_of_Min_Amount  \
# 0               22 Years and 9 Months                    No
# 1              22 Years and 10 Months                    No
# 2   <function mean at 0x7d2a649015a0>                    No
# 3               23 Years and 0 Months                    No
# 4               27 Years and 3 Months                    No
# 5               27 Years and 4 Months                    No
# 6               27 Years and 5 Months                    No
# 7               27 Years and 6 Months                    No
# 8               18 Years and 5 Months                    No
# 9               18 Years and 6 Months                    No
# 10              18 Years and 7 Months                    No
# 11  <function mean at 0x7d2a649015a0>                    No
# 12             17 Years and 11 Months                    No
# 13              18 Years and 0 Months                    No
# 14              18 Years and 1 Months                    No
# 15              18 Years and 2 Months                    No
# 16              31 Years and 4 Months                   Yes
# 17              31 Years and 5 Months                   Yes
# 18  <function mean at 0x7d2a649015a0>                   Yes
# 19              31 Years and 7 Months                   Yes
#
#    Total_EMI_per_month Amount_invested_monthly  \
# 0            49.574949      236.64268203272135
# 1            49.574949      21.465380264657146
# 2            49.574949      148.23393788500925
# 3            49.574949       39.08251089460281
# 4            18.816215      39.684018417945296
# 5            18.816215      251.62736875017606
# 6            18.816215       72.68014533363515
# 7            18.816215      153.53448761392985
# 8           246.992319      397.50365354404653
# 9           246.992319       453.6151305781054
# 10          246.992319       841.2322359154716
# 11          246.992319      506.30777972175247
# 12           16.415452       69.10700584725082
# 13           16.415452      29.393311428984493
# 14           16.415452      191.88624358002707
# 15           16.415452      233.93341714114612
# 16                 0.0       59.36605764456292
# 17                 0.0      113.45265630966415
# 18                 0.0       46.56457517290926
# 19                 0.0       181.0072171318061
#
#                    Payment_Behaviour     Monthly_Balance
# 0     Low_spent_Small_value_payments  186.26670208571772
# 1   High_spent_Medium_value_payments  361.44400385378196
# 2    Low_spent_Medium_value_payments  264.67544623342997
# 3   High_spent_Medium_value_payments  343.82687322383634
# 4    High_spent_Large_value_payments   485.2984336755923
# 5     Low_spent_Large_value_payments   303.3550833433617
# 6    High_spent_Large_value_payments  452.30230675990265
# 7                             !@9#%8  421.44796447960783
# 8    Low_spent_Medium_value_payments   854.2260270022115
# 9     Low_spent_Large_value_payments   788.1145499681528
# 10   Low_spent_Medium_value_payments   410.4974446307865
# 11  High_spent_Medium_value_payments   715.4219008245058
# 12  High_spent_Medium_value_payments   425.7266258262577
# 13   High_spent_Large_value_payments    455.440320244524
# 14   Low_spent_Medium_value_payments   332.9473880934814
# 15    Low_spent_Small_value_payments  300.90021453236227
# 16  High_spent_Medium_value_payments  475.96485902210367
# 17  High_spent_Medium_value_payments   421.8782603570025
# 18  High_spent_Medium_value_payments   488.7663414937574
# 19    Low_spent_Small_value_payments   394.3236995348605

# %%
df.drop(["Name","ID","Customer_ID"],axis=1,inplace=True)

# %%
num_cols=['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts','Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
       'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
       'Num_Credit_Inquiries', 'Outstanding_Debt',
       'Credit_Utilization_Ratio', 'Total_EMI_per_month',
       'Amount_invested_monthly', 'Monthly_Balance']

df[num_cols]=df[num_cols].apply(pd.to_numeric,errors="coerce")

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)
# Out:
# <ipython-input-17-f1dfd8b2652b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df["Age"].mean()
# Out:
# 110.12099404498875

# %%
df.loc[df['Age'] <= 0, 'Age'] = 50
df.loc[df['Age'] >= 100, 'Age'] = 50

# %%
df["Age"].mean()
# Out:
# 35.06106

# %%
df.isnull().sum()
# Out:
# Month                          0
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                 2436
# Type_of_Loan                   0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      4925
# Changed_Credit_Limit        1059
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt             491
# Credit_Utilization_Ratio       0
# Credit_History_Age             0
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4446
# Payment_Behaviour              0
# Monthly_Balance              568
# dtype: int64

# %%
df["Monthly_Inhand_Salary"].fillna(np.mean(df["Monthly_Inhand_Salary"]),inplace=True)
df["Num_of_Delayed_Payment"].fillna(30, inplace=True)
df["Changed_Credit_Limit"].fillna(10, inplace=True)
df["Num_Credit_Inquiries"].fillna(28, inplace=True)
df["Outstanding_Debt"].fillna(1426, inplace=True)
df["Amount_invested_monthly"].fillna(195, inplace=True)
df["Monthly_Balance"].fillna(402, inplace=True)
df["Num_of_Loan"].fillna(3, inplace=True)
# Out:
# <ipython-input-22-9614f2e21f65>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Monthly_Inhand_Salary"].fillna(np.mean(df["Monthly_Inhand_Salary"]),inplace=True)
# <ipython-input-22-9614f2e21f65>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Num_of_Delayed_Payment"].fillna(30, inplace=True)
# <ipython-input-22-9614f2e21f65>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Changed_Credit_Limit"].fillna(10, inplace=True)
# <ipython-input-22-9614f2e21f65>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Num_Credit_Inquiries"].fillna(28, inplace=True)
# <ipython-input-22-9614f2e21f65>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Outstanding_Debt"].fillna(1426, inplace=True)
# <ipython-input-22-9614f2e21f65>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Amount_invested_monthly"].fillna(195, inplace=True)
# <ipython-input-22-9614f2e21f65>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Monthly_Balance"].fillna(402, inplace=True)
# <ipython-input-22-9614f2e21f65>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Num_of_Loan"].fillna(3, inplace=True)

# %%
df["Num_of_Delayed_Payment"].value_counts()
# Out:
# Num_of_Delayed_Payment
# 30.0      4925
# 19.0      2622
# 15.0      2594
# 18.0      2570
# 16.0      2548
#           ...
# 288.0        1
# 3556.0       1
# 3393.0       1
# 4351.0       1
# 2034.0       1
# Name: count, Length: 399, dtype: int64

# %%
df.loc[df['Num_of_Loan'] < 0, 'Age'] = 3
df.loc[df['Num_of_Loan'] > 'Age'] = 310,

# %%
df["Num_of_Loan"].mean()
# Out:
# 3.25474

# %%
df.head()
# Out:
#        Month   Age          SSN Occupation  Annual_Income  \
# 0  September  23.0  821-00-0265  Scientist       19114.12
# 1    October  24.0  821-00-0265  Scientist       19114.12
# 2   November  24.0  821-00-0265  Scientist       19114.12
# 3   December  50.0  821-00-0265  Scientist       19114.12
# 4  September  28.0  004-07-5839    _______       34847.84
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0            1824.843333                  3                4              3
# 1            1824.843333                  3                4              3
# 2            1824.843333                  3                4              3
# 3            4182.004291                  3                4              3
# 4            3037.986667                  2                4              6
#
#    Num_of_Loan                                       Type_of_Loan  \
# 0          4.0  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1          4.0  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2          4.0  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3          4.0  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4          1.0                                Credit-Builder Loan
#
#    Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                    3                     7.0                 11.27
# 1                    3                     9.0                 13.27
# 2                   -1                     4.0                 12.27
# 3                    4                     5.0                 11.27
# 4                    3                     1.0                  5.42
#
#    Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 0                2022.0       Good            809.98
# 1                   4.0       Good            809.98
# 2                   4.0       Good            809.98
# 3                   4.0       Good            809.98
# 4                   5.0       Good            605.03
#
#    Credit_Utilization_Ratio                 Credit_History_Age  \
# 0                 35.030402              22 Years and 9 Months
# 1                 33.053114             22 Years and 10 Months
# 2                 33.811894  <function mean at 0x7d2a649015a0>
# 3                 32.430559              23 Years and 0 Months
# 4                 25.926822              27 Years and 3 Months
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            49.574949               236.642682
# 1                    No            49.574949                21.465380
# 2                    No            49.574949               148.233938
# 3                    No            49.574949                39.082511
# 4                    No            18.816215                39.684018
#
#                   Payment_Behaviour  Monthly_Balance
# 0    Low_spent_Small_value_payments       186.266702
# 1  High_spent_Medium_value_payments       361.444004
# 2   Low_spent_Medium_value_payments       264.675446
# 3  High_spent_Medium_value_payments       343.826873
# 4   High_spent_Large_value_payments       485.298434

# %%
headers = df.columns

# Convert to a list if you want to see them as a list
headers_list = df.columns.tolist()

print(headers)       # Output as Index object
print(headers_list)  # Output as list
# Out:
# Index(['Month', 'Age', 'SSN', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')
# ['Month', 'Age', 'SSN', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']

# %%
df["Credit_Mix"].value_counts()
# Out:
# Credit_Mix
# Standard    18379
# Good        12260
# _            9805
# Bad          9556
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Month                       0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# dtype: int64

# %%
sns.countplot(data=df, x="Credit_Mix")
plt.show()

# %%
df["Occupation"].unique()
# Out:
# array(['Scientist', '_______', 'Teacher', 'Engineer', 'Entrepreneur',
#        'Developer', 'Lawyer', 'Media_Manager', 'Doctor', 'Journalist',
#        'Manager', 'Accountant', 'Musician', 'Mechanic', 'Writer',
#        'Architect'], dtype=object)

# %%
df["Occupation"].replace("_______","Others",inplace=True)
df["Occupation"].unique()
# Out:
# <ipython-input-34-9c37d924d5a1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Occupation"].replace("_______","Others",inplace=True)
# array(['Scientist', 'Others', 'Teacher', 'Engineer', 'Entrepreneur',
#        'Developer', 'Lawyer', 'Media_Manager', 'Doctor', 'Journalist',
#        'Manager', 'Accountant', 'Musician', 'Mechanic', 'Writer',
#        'Architect'], dtype=object)

# %%
sns.countplot(x=df["Occupation"])
plt.xticks(rotation=80)
plt.show()

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Others           3438
# Lawyer           3324
# Engineer         3212
# Architect        3195
# Mechanic         3168
# Developer        3146
# Accountant       3133
# Media_Manager    3130
# Scientist        3104
# Teacher          3103
# Entrepreneur     3103
# Journalist       3037
# Doctor           3027
# Manager          3000
# Musician         2947
# Writer           2933
# Name: count, dtype: int64

# %%
sns.boxplot(df,y="Occupation",x="Monthly_Inhand_Salary")
plt.legend()
plt.show()
# Out:
# <ipython-input-37-79954b11740a>:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.boxplot(df,y="Credit_Mix",x="Monthly_Inhand_Salary")
plt.legend()
plt.show()
# Out:
# <ipython-input-39-a9a0bfdc92f3>:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.boxplot(df,y="Credit_Mix",x="Monthly_Balance")
plt.legend()
plt.show()
# Out:
# <ipython-input-41-3728d01c3c75>:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.boxplot(df,x="Month",y="Monthly_Balance")
plt.legend()
plt.show()
# Out:
# <ipython-input-42-48bde7ab760e>:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.histplot(df["Monthly_Balance"])
plt.show()

# %%
sns.histplot(df["Monthly_Inhand_Salary"])
plt.show()

# %%
sns.barplot(df,x='Occupation',y='Age',width=0.5)
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(13,10))
sns.lineplot(df,x='Month',y='Age', hue="Occupation",palette="viridis", linewidth=3)
plt.xticks(rotation=80)
plt.legend(loc="right",bbox_to_anchor=(0.67, 0., 0.5, 0.442))
plt.show()

# %%
plt.figure(figsize=(13,10))
sns.lineplot(df,x='Month',y='Age', hue="Credit_Mix",palette="viridis", linewidth=3)
plt.xticks(rotation=80)
plt.legend(loc="right",bbox_to_anchor=(0.67, 0., 0.5, 0.442))
plt.show()

# %%
df.head(3)
# Out:
#        Month   Age          SSN Occupation  Annual_Income  \
# 0  September  23.0  821-00-0265  Scientist       19114.12
# 1    October  24.0  821-00-0265  Scientist       19114.12
# 2   November  24.0  821-00-0265  Scientist       19114.12
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0            1824.843333                  3                4              3
# 1            1824.843333                  3                4              3
# 2            1824.843333                  3                4              3
#
#    Num_of_Loan                                       Type_of_Loan  \
# 0          4.0  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1          4.0  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2          4.0  Auto Loan, Credit-Builder Loan, Personal Loan,...
#
#    Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                    3                     7.0                 11.27
# 1                    3                     9.0                 13.27
# 2                   -1                     4.0                 12.27
#
#    Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 0                2022.0       Good            809.98
# 1                   4.0       Good            809.98
# 2                   4.0       Good            809.98
#
#    Credit_Utilization_Ratio                 Credit_History_Age  \
# 0                 35.030402              22 Years and 9 Months
# 1                 33.053114             22 Years and 10 Months
# 2                 33.811894  <function mean at 0x7d2a649015a0>
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            49.574949               236.642682
# 1                    No            49.574949                21.465380
# 2                    No            49.574949               148.233938
#
#                   Payment_Behaviour  Monthly_Balance
# 0    Low_spent_Small_value_payments       186.266702
# 1  High_spent_Medium_value_payments       361.444004
# 2   Low_spent_Medium_value_payments       264.675446

# %%
df['Credit_Mix'].unique()
# Out:
# array(['Good', '_', 'Standard', 'Bad'], dtype=object)

# %%
df['Payment_Behaviour'].unique()
# Out:
# array(['Low_spent_Small_value_payments',
#        'High_spent_Medium_value_payments',
#        'Low_spent_Medium_value_payments',
#        'High_spent_Large_value_payments',
#        'Low_spent_Large_value_payments', '!@9#%8',
#        'High_spent_Small_value_payments'], dtype=object)

# %%
# Get all column headers
headers = df.columns

# Convert to a list if you want to see them as a list
headers_list = df.columns.tolist()

print(headers)       # Output as Index object
print(headers_list)  # Output as list
# Out:
# Index(['Month', 'Age', 'SSN', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')
# ['Month', 'Age', 'SSN', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']

# %%
headers = df.columns[0]

# %%
print(df['Credit_Mix'].head(20))
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     0
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# 14    1
# 15    1
# 16    0
# 17    2
# 18    2
# 19    2
# Name: Credit_Mix, dtype: int64

# %%
df['Payment_of_Min_Amount'] = pd.to_numeric(df['Payment_of_Min_Amount'], errors='coerce')

# %%
df['Credit_Mix'] = df['Credit_Mix'].map({'_':0, 'Good':1, 'Standard':2, 'Bad':3})

# %%
df['Month'] = df['Month'].map({'January':1, 'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 'July':7,'August':8})

# %%
df['Month'] = df['Month'].map({'January':1, 'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 'July':7,'August':8,'September':9, 'October': 10, 'November': 11, 'December': 12})
print(df['Month'].head(20))
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# Name: Month, dtype: float64

# %%
df['Payment_Behaviour'] = df['Payment_Behaviour'].map({'High_spent_Small_value_payments':4,
       'Low_spent_Large_value_payments':2,
       'Low_spent_Medium_value_payments':1,
       'Low_spent_Small_value_payments':0,
       'High_spent_Medium_value_payments':5, '!@9#%8':7,
       'High_spent_Large_value_payments':6})

print(df['Payment_Behaviour'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 49995   NaN
# 49996   NaN
# 49997   NaN
# 49998   NaN
# 49999   NaN
# Name: Payment_Behaviour, Length: 50000, dtype: float64

# %%
dfd = pd.get_dummies(df,columns=['Occupation'],drop_first=True)

# %%
dfd.shape
# Out:
# (50000, 38)

# %%
dfd.head()
# Out:
#    Month   Age          SSN  Annual_Income  Monthly_Inhand_Salary  \
# 0    NaN  23.0  821-00-0265       19114.12            1824.843333
# 1    NaN  24.0  821-00-0265       19114.12            1824.843333
# 2    NaN  24.0  821-00-0265       19114.12            1824.843333
# 3    NaN  50.0  821-00-0265       19114.12            4182.004291
# 4    NaN  28.0  004-07-5839       34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3                4              3          4.0
# 1                  3                4              3          4.0
# 2                  3                4              3          4.0
# 3                  3                4              3          4.0
# 4                  2                4              6          1.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 2  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# 3  Auto Loan, Credit-Builder Loan, Personal Loan,...                    4
# 4                                Credit-Builder Loan                    3
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                     7.0                 11.27                2022.0
# 1                     9.0                 13.27                   4.0
# 2                     4.0                 12.27                   4.0
# 3                     5.0                 11.27                   4.0
# 4                     1.0                  5.42                   5.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0           1            809.98                 35.030402
# 1           1            809.98                 33.053114
# 2           1            809.98                 33.811894
# 3           1            809.98                 32.430559
# 4           1            605.03                 25.926822
#
#                   Credit_History_Age Payment_of_Min_Amount  \
# 0              22 Years and 9 Months                    No
# 1             22 Years and 10 Months                    No
# 2  <function mean at 0x7d2a649015a0>                    No
# 3              23 Years and 0 Months                    No
# 4              27 Years and 3 Months                    No
#
#    Total_EMI_per_month  Amount_invested_monthly  Payment_Behaviour  \
# 0            49.574949               236.642682                NaN
# 1            49.574949                21.465380                NaN
# 2            49.574949               148.233938                NaN
# 3            49.574949                39.082511                NaN
# 4            18.816215                39.684018                NaN
#
#    Monthly_Balance  Occupation_Architect  Occupation_Developer  \
# 0       186.266702                 False                 False
# 1       361.444004                 False                 False
# 2       264.675446                 False                 False
# 3       343.826873                 False                 False
# 4       485.298434                 False                 False
#
#    Occupation_Doctor  Occupation_Engineer  Occupation_Entrepreneur  \
# 0              False                False                    False
# 1              False                False                    False
# 2              False                False                    False
# 3              False                False                    False
# 4              False                False                    False
#
#    Occupation_Journalist  Occupation_Lawyer  Occupation_Manager  \
# 0                  False              False               False
# 1                  False              False               False
# 2                  False              False               False
# 3                  False              False               False
# 4                  False              False               False
#
#    Occupation_Mechanic  Occupation_Media_Manager  Occupation_Musician  \
# 0                False                     False                False
# 1                False                     False                False
# 2                False                     False                False
# 3                False                     False                False
# 4                False                     False                False
#
#    Occupation_Others  Occupation_Scientist  Occupation_Teacher  \
# 0              False                  True               False
# 1              False                  True               False
# 2              False                  True               False
# 3              False                  True               False
# 4               True                 False               False
#
#    Occupation_Writer
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %%
print(df[df['Month'].isna()])
# Out:
#        Month   Age          SSN Occupation  Annual_Income  \
# 0        NaN  23.0  821-00-0265  Scientist       19114.12
# 1        NaN  24.0  821-00-0265  Scientist       19114.12
# 2        NaN  24.0  821-00-0265  Scientist       19114.12
# 3        NaN  50.0  821-00-0265  Scientist       19114.12
# 4        NaN  28.0  004-07-5839     Others       34847.84
# ...      ...   ...          ...        ...            ...
# 49995    NaN  50.0  031-35-0942  Architect       20002.88
# 49996    NaN  25.0  078-73-5990   Mechanic       39628.99
# 49997    NaN  25.0  078-73-5990   Mechanic       39628.99
# 49998    NaN  25.0  078-73-5990   Mechanic       39628.99
# 49999    NaN  25.0  078-73-5990   Mechanic       39628.99
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0                1824.843333                  3                4
# 1                1824.843333                  3                4
# 2                1824.843333                  3                4
# 3                4182.004291                  3                4
# 4                3037.986667                  2                4
# ...                      ...                ...              ...
# 49995            1929.906667                 10                8
# 49996            4182.004291                  4                6
# 49997            3359.415833                  4                6
# 49998            4182.004291                  4                6
# 49999            3359.415833                  4                6
#
#        Interest_Rate  Num_of_Loan  \
# 0                  3          4.0
# 1                  3          4.0
# 2                  3          4.0
# 3                  3          4.0
# 4                  6          1.0
# ...              ...          ...
# 49995             29          5.0
# 49996              7          3.0
# 49997              7          2.0
# 49998              7          3.0
# 49999              7          2.0
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 0      Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 2      Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# 3      Auto Loan, Credit-Builder Loan, Personal Loan,...                    4
# 4                                    Credit-Builder Loan                    3
# ...                                                  ...                  ...
# 49995  Personal Loan, Auto Loan, Mortgage Loan, Stude...                   33
# 49996                        Auto Loan, and Student Loan                   20
# 49997                        Auto Loan, and Student Loan                   23
# 49998                        Auto Loan, and Student Loan                   21
# 49999                        Auto Loan, and Student Loan                   22
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                         7.0                 11.27                2022.0
# 1                         9.0                 13.27                   4.0
# 2                         4.0                 12.27                   4.0
# 3                         5.0                 11.27                   4.0
# 4                         1.0                  5.42                   5.0
# ...                       ...                   ...                   ...
# 49995                    25.0                 18.31                  12.0
# 49996                    30.0                 11.50                   7.0
# 49997                     5.0                 13.50                   7.0
# 49998                    30.0                 11.50                   7.0
# 49999                     5.0                 11.50                   7.0
#
#        Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0               1            809.98                 35.030402
# 1               1            809.98                 33.053114
# 2               1            809.98                 33.811894
# 3               1            809.98                 32.430559
# 4               1            605.03                 25.926822
# ...           ...               ...                       ...
# 49995           0           3571.70                 34.780553
# 49996           1            502.38                 27.758522
# 49997           1            502.38                 36.858542
# 49998           1            502.38                 39.139840
# 49999           0            502.38                 34.108530
#
#                       Credit_History_Age Payment_of_Min_Amount  \
# 0                  22 Years and 9 Months                    No
# 1                 22 Years and 10 Months                    No
# 2      <function mean at 0x7d2a649015a0>                    No
# 3                  23 Years and 0 Months                    No
# 4                  27 Years and 3 Months                    No
# ...                                  ...                   ...
# 49995  <function mean at 0x7d2a649015a0>                   Yes
# 49996             31 Years and 11 Months                    NM
# 49997              32 Years and 0 Months                    No
# 49998              32 Years and 1 Months                    No
# 49999              32 Years and 2 Months                    No
#
#        Total_EMI_per_month  Amount_invested_monthly  Payment_Behaviour  \
# 0                49.574949               236.642682                NaN
# 1                49.574949                21.465380                NaN
# 2                49.574949               148.233938                NaN
# 3                49.574949                39.082511                NaN
# 4                18.816215                39.684018                NaN
# ...                    ...                      ...                ...
# 49995            60.964772               146.486325                NaN
# 49996            35.104023               181.442999                NaN
# 49997            35.104023               195.000000                NaN
# 49998            35.104023                97.598580                NaN
# 49999            35.104023               220.457878                NaN
#
#        Monthly_Balance
# 0           186.266702
# 1           361.444004
# 2           264.675446
# 3           343.826873
# 4           485.298434
# ...                ...
# 49995       275.539570
# 49996       409.394562
# 49997       349.726332
# 49998       463.238981
# 49999       360.379683
#
# [50000 rows x 24 columns]

# %%
y = dfd['Credit_Mix']
x = dfd.drop(['Credit_Mix','Type_of_Loan','SSN','Credit_History_Age',
              'Num_of_Delayed_Payment'],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.20,random_state=42)

# %%
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, train_size=0.50, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,accuracy_score,mean_absolute_error,mean_squared_error,r2_score,log_loss,f1_score,jaccard_score
